# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import math
import scipy
import cmath

# %%
x,y,z,k,q,r,R = sp.symbols('x,y,z,k,q,r,R',real =True,positive = True)

# %%
Enc1 = k*q*r/(R**3)
Enc1
# Out:
# k*q*r/R**3

# %%
Enc2 = k*q/(r**2)
Enc2
# Out:
# k*q/r**2

# %%
R = 5
font1 = {'family':'serif','color':'black','size':15}

def f(x):
    return x

def g(x):
    return 1/(x**2)

x = np.linspace(R,30,3000)
y = g(x)
x1 = np.array([0,2,3,4])
y1 = np.array([0,0.020,0.030,0.040])
x2 = np.array([4.7,4.7,4.7,4.7,4.7,4.7])
y2 = np.array([0.001,0.005,0.020,0.025,0.035,0.040])

plt.plot(x,y)
plt.plot(x1,y1)
plt.plot(x2,y2 , linestyle = 'dashed')

plt.xlabel("R" , fontdict = font1)
plt.ylabel("E",fontdict = font1)
plt.show()

# %%
Enc1 = k*q*r/(R**3)
Enc1
# Out:
# k*q*r/R**3

# %%
x = np.linspace(1,10,10)
y = np.linspace(1,10,10)
(x,y) = np.meshgrid(x,y)

u = x/(np.sqrt(x**2 + y**2))
v = y/(np.sqrt(x**2 + y**2))

plt.quiver(x,y,u,v)
plt.show()

# %%
Enc2 = k*q/(r**2)
Enc2
# Out:
# k*q/r**2

# %%
x = np.linspace(1,10,10)
y = np.linspace(1,10,10)
(x,y) = np.meshgrid(x,y)

u = x/((x**2 + y**2)**(3/2))
v = y/((x**2 + y**2)**(3/2))

plt.quiver(x,y,u,v)
plt.show()
