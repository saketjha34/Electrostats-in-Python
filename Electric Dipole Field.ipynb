# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import math
x,y,z,k = sp.symbols('x y z')

# %%
-x
# Out:
# -x

# %%
kq = 1
r = 1

# %%
x = np.linspace(0,10,11)
y = np.linspace(0,10,11)

(x,y) = np.meshgrid(x,y)

u = -x
v = 0

plt.quiver(x,y,u,v)
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.title("Vector field due to Electric dipole on axial position ")
plt.show()
