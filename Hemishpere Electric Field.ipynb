# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import math

# %%
x,y,z,r = sp.symbols('x,y,z,r')

# %%
-y
# Out:
# -y

# %%
sigma = 1
epsilon = 1

x = np.linspace(0 , 10 , 11)
y = np.linspace(0 , 10 , 11)

(x,y) = np.meshgrid(x,y)

u = 0
v = -y

plt.quiver(x,y,u,v)
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.title("Electic field at the centre of Hemisphere")
plt.show()
