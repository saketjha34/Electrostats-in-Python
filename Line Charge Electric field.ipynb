# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import math
x,y,z,ε0,λ,π = sp.symbols('x y z ε0 λ π')

# %%
E = λ/(2*π*ε0*x)
E
# Out:
# λ/(2*x*ε0*π)

# %%
λ = 1
ε0 = 1
π = math.pi
def f(x):
    return 1/x

x = np.linspace(1,10,100)
y = f(x)

plt.plot(x,y)
plt.title("E = λ/(2πε0x)")
plt.xlabel("x-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
kq = 1
x = np.linspace(1,10,11)
y = np.linspace(1,10,11)

(x,y) = np.meshgrid(x,y)

u = 1/x
v = 0

plt.quiver(x,y,u,v)
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.title("Electric Field Due To An Infinitely Long Straight Uniformly Charged Wire ")
plt.show()
